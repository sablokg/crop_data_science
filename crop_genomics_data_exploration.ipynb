# %%
import pandas as pd
import seaborn as sns
import numpy as np
import pingouin as pg
from sklearn import *
import csv

# %%
# Complete crop genomics analysis
# reading the file, summary statistics, calculating null values, dropping duplicates, reseting the index, geomapping statistics, pair plots, linear regression, Multiple regression, KNN analysis
# The ML regression methods included ML Regression, SVR Linear Kernel, SVR Gaussian Kernel, SVR Polynomial Kernel, SVR Sigmoid Kernel, RFR, and GBDTR 
data=pd.read_csv('/Users/dr.gauravsablok/Desktop/Reading/Crop_Genomics/Oceania.csv', sep= ',')

# %%
# Checking the data head
data.head()
# Out:
#    Area Code       Area  Item Code                              Item  \
# 0         10  Australia        221               Almonds, with shell
# 1         10  Australia        221               Almonds, with shell
# 2         10  Australia        221               Almonds, with shell
# 3         10  Australia        711  Anise, badian, fennel, coriander
# 4         10  Australia        711  Anise, badian, fennel, coriander
#
#    Element Code         Element    Unit  Y1961 Y1961F  Y1962  ...     Y2015  \
# 0          5312  Area harvested      ha    NaN      M    NaN  ...   28190.0
# 1          5419           Yield   hg/ha    NaN    NaN    NaN  ...   45221.0
# 2          5510      Production  tonnes    NaN      M    NaN  ...  127479.0
# 3          5312  Area harvested      ha    NaN      M    NaN  ...     989.0
# 4          5419           Yield   hg/ha    NaN    NaN    NaN  ...   11608.0
#
#    Y2015F     Y2016  Y2016F     Y2017  Y2017F     Y2018  Y2018F     Y2019  \
# ...

# %%
# Checking the data tail
data.tail()
# Out:
#       Area Code     Area  Item Code                     Item  Element Code  \
# 1649        155  Vanuatu       1720  Roots and Tubers, Total          5419
# 1650        155  Vanuatu       1720  Roots and Tubers, Total          5510
# 1651        155  Vanuatu       1735       Vegetables Primary          5312
# 1652        155  Vanuatu       1735       Vegetables Primary          5419
# 1653        155  Vanuatu       1735       Vegetables Primary          5510
#
#              Element    Unit     Y1961 Y1961F     Y1962  ...     Y2015  \
# 1649           Yield   hg/ha  225455.0     Fc  227273.0  ...   82467.0
# 1650      Production  tonnes   24800.0      A   25000.0  ...   52251.0
# 1651  Area harvested      ha     200.0      A     210.0  ...     801.0
# 1652           Yield   hg/ha  150000.0     Fc  150000.0  ...  164819.0
# 1653      Production  tonnes    3000.0      A    3150.0  ...   13202.0
#
#       Y2015F     Y2016  Y2016F     Y2017  Y2017F     Y2018  Y2018F     Y2019  \
# ...

# %%
# Checking the data index
data.index
# Out:
# RangeIndex(start=0, stop=1654, step=1)

# %%
# Checking the data shape
data.shape
# Out:
# (1654, 125)

# %%
# Checking the data size
data.size
# Out:
# 206750

# %%
# Checking the data columns
data.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Unit', 'Y1961', 'Y1961F', 'Y1962',
#        ...
#        'Y2015', 'Y2015F', 'Y2016', 'Y2016F', 'Y2017', 'Y2017F', 'Y2018',
#        'Y2018F', 'Y2019', 'Y2019F'],
#       dtype='object', length=125)

# %%
# Checking the data count and means
data.count().mean()
# Out:
# 1377.36

# %%
# Checking the data descriptive statistics
data.describe().T
# Out:
#                count           mean           std     min     25%     50%  \
# Area Code     1654.0     113.555623  7.397403e+01    10.0    47.0   148.0
# Item Code     1654.0     742.074365  6.127301e+02    15.0   267.0   521.0
# Element Code  1654.0    5414.327086  8.180195e+01  5312.0  5312.0  5419.0
# Y1961         1343.0  131754.595681  1.572220e+06     1.0   376.0  5100.0
# Y1962         1352.0  188543.391272  2.952969e+06     1.0   405.0  5452.0
# ...              ...            ...           ...     ...     ...     ...
# Y2015         1561.0  206594.717489  1.747487e+06     0.0   781.0  6931.0
# Y2016         1559.0  206134.430404  1.747095e+06     0.0   733.0  6869.0
# Y2017         1583.0  231449.416930  2.113631e+06     0.0   596.0  6543.0
# Y2018         1583.0  202221.586229  1.688364e+06     0.0   604.0  6501.0
# Y2019         1582.0  187373.750948  1.562523e+06     0.0   626.0  6379.5
#
#                    75%          max
# Area Code       159.00        244.0
# ...

# %%
# Printing each columns
for col in data:
    print(col)
# Checking the data rows
for row in data:
    print(data[row])

# %%
# Cross tabbing the data according to Area and Item
data_tab = pd.crosstab(index = data["Area"], columns = data["Item"])

# %%
# Checking the data head of the cross tabbed data
data_tab.head()
# Out:
# Item              Almonds, with shell  Anise, badian, fennel, coriander  \
# Area
# Australia                           3                                 3
# Cook Islands                        0                                 0
# Fiji                                0                                 0
# French Polynesia                    0                                 0
# Kiribati                            0                                 0
#
# Item              Apples  Apricots  Asparagus  Avocados  Bananas  Barley  \
# Area
# Australia              3         3          3         3        3       3
# Cook Islands           0         0          0         3        3       0
# Fiji                   0         0          0         0        3       0
# French Polynesia       0         0          0         3        3       0
# Kiribati               0         0          0         0        3       0
#
# Item              Beans, dry  Beans, green  ...  Triticale  Vanilla  \
# ...

# %%
# Counting the duplicated values
data.duplicated().count()
# Out:
# 1654

# %%
# Counting the empty values
data.isna().sum()
# Out:
# Area Code         0
# Area              0
# Item Code         0
# Item              0
# Element Code      0
#                ...
# Y2017F          239
# Y2018            71
# Y2018F          202
# Y2019            72
# Y2019F          225
# Length: 125, dtype: int64

# %%
# Making a working copy of the data
data_analysis = data.copy()

# %%
data_analysis.dtypes
# Out:
# Area Code         int64
# Area             object
# Item Code         int64
# Item             object
# Element Code      int64
#                  ...
# Y2017F           object
# Y2018           float64
# Y2018F           object
# Y2019           float64
# Y2019F           object
# Length: 125, dtype: object

# %%
data_analysis.drop_duplicates(inplace=True)

# %%
# Identifying the unique places in the dataframe for clusterting and plotting and subsetting
data_analysis['Area'].unique()
# Out:
# array(['Australia', 'Cook Islands', 'Fiji', 'French Polynesia',
#        'Kiribati', 'Marshall Islands', 'Micronesia (Federated States of)',
#        'Nauru', 'New Caledonia', 'New Zealand', 'Niue',
#        'Papua New Guinea', 'Samoa', 'Solomon Islands', 'Tokelau', 'Tonga',
#        'Tuvalu', 'Vanuatu'], dtype=object)

# %%
# Describing the quantile percentage variation across the data
data.describe(percentiles=[0.3, 0.5, 0.7])
# Out:
#          Area Code    Item Code  Element Code         Y1961         Y1962  \
# count  1654.000000  1654.000000   1654.000000  1.343000e+03  1.352000e+03
# mean    113.555623   742.074365   5414.327086  1.317546e+05  1.885434e+05
# std      73.974033   612.730071     81.801946  1.572220e+06  2.952969e+06
# min      10.000000    15.000000   5312.000000  1.000000e+00  1.000000e+00
# 30%      66.000000   388.000000   5312.000000  7.000000e+02  7.479000e+02
# 50%     148.000000   521.000000   5419.000000  5.100000e+03  5.452000e+03
# 70%     156.000000   687.000000   5510.000000  2.770000e+04  2.805500e+04
# max     244.000000  1841.000000   5510.000000  5.317917e+07  1.043523e+08
#
#               Y1963         Y1964         Y1965         Y1966         Y1967  \
# count  1.352000e+03  1.356000e+03  1.353000e+03  1.348000e+03  1.348000e+03
# mean   1.882656e+05  1.629606e+05  1.444617e+05  1.602158e+05  1.192592e+05
# ...

# %%
# Describing the quantile percentage variation across the selected data
data_analysis.describe(percentiles=[0.3, 0.5, 0.7])
# Out:
#          Area Code    Item Code  Element Code         Y1961         Y1962  \
# count  1654.000000  1654.000000   1654.000000  1.343000e+03  1.352000e+03
# mean    113.555623   742.074365   5414.327086  1.317546e+05  1.885434e+05
# std      73.974033   612.730071     81.801946  1.572220e+06  2.952969e+06
# min      10.000000    15.000000   5312.000000  1.000000e+00  1.000000e+00
# 30%      66.000000   388.000000   5312.000000  7.000000e+02  7.479000e+02
# 50%     148.000000   521.000000   5419.000000  5.100000e+03  5.452000e+03
# 70%     156.000000   687.000000   5510.000000  2.770000e+04  2.805500e+04
# max     244.000000  1841.000000   5510.000000  5.317917e+07  1.043523e+08
#
#               Y1963         Y1964         Y1965         Y1966         Y1967  \
# count  1.352000e+03  1.356000e+03  1.353000e+03  1.348000e+03  1.348000e+03
# mean   1.882656e+05  1.629606e+05  1.444617e+05  1.602158e+05  1.192592e+05
# ...

# %%
# Since the data contains a combination so selecting the columns where the value is float
data.describe(include=[float])
# Out:
#               Y1961         Y1962         Y1963         Y1964         Y1965  \
# count  1.343000e+03  1.352000e+03  1.352000e+03  1.356000e+03  1.353000e+03
# mean   1.317546e+05  1.885434e+05  1.882656e+05  1.629606e+05  1.444617e+05
# std    1.572220e+06  2.952969e+06  2.891302e+06  1.972332e+06  1.603859e+06
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    3.760000e+02  4.050000e+02  4.387500e+02  4.300000e+02  4.170000e+02
# 50%    5.100000e+03  5.452000e+03  5.733000e+03  5.666000e+03  5.450000e+03
# 75%    4.865850e+04  4.708225e+04  4.777700e+04  4.823500e+04  4.815000e+04
# max    5.317917e+07  1.043523e+08  1.020497e+08  6.545600e+07  5.201200e+07
#
#               Y1966         Y1967         Y1968         Y1969         Y1970  \
# count  1.348000e+03  1.348000e+03  1.354000e+03  1.357000e+03  1.360000e+03
# mean   1.602158e+05  1.192592e+05  1.313118e+05  1.189724e+05  1.184796e+05
# ...

# %%
# Since the data contains a combination so selecting the columns where the value is float
data_analysis.describe(include=[float])
# Out:
#               Y1961         Y1962         Y1963         Y1964         Y1965  \
# count  1.343000e+03  1.352000e+03  1.352000e+03  1.356000e+03  1.353000e+03
# mean   1.317546e+05  1.885434e+05  1.882656e+05  1.629606e+05  1.444617e+05
# std    1.572220e+06  2.952969e+06  2.891302e+06  1.972332e+06  1.603859e+06
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    3.760000e+02  4.050000e+02  4.387500e+02  4.300000e+02  4.170000e+02
# 50%    5.100000e+03  5.452000e+03  5.733000e+03  5.666000e+03  5.450000e+03
# 75%    4.865850e+04  4.708225e+04  4.777700e+04  4.823500e+04  4.815000e+04
# max    5.317917e+07  1.043523e+08  1.020497e+08  6.545600e+07  5.201200e+07
#
#               Y1966         Y1967         Y1968         Y1969         Y1970  \
# count  1.348000e+03  1.348000e+03  1.354000e+03  1.357000e+03  1.360000e+03
# mean   1.602158e+05  1.192592e+05  1.313118e+05  1.189724e+05  1.184796e+05
# ...

# %%
# Checking the null values in the data_analysis dataframe
data_analysis.isnull().sum().sum()
# Out:
# 34580

# %%
# Checking where the null values in the data_analysis dataframe are present
data_analysis.isnull().sum()
# Out:
# Area Code         0
# Area              0
# Item Code         0
# Item              0
# Element Code      0
#                ...
# Y2017F          239
# Y2018            71
# Y2018F          202
# Y2019            72
# Y2019F          225
# Length: 125, dtype: int64

# %%
data_analysis_dropna = data_analysis.copy()

# %%
data_analysis_dropna.dropna(inplace=True)

# %%
data_analysis.head()
# Out:
#    Area Code       Area  Item Code                              Item  \
# 0         10  Australia        221               Almonds, with shell
# 1         10  Australia        221               Almonds, with shell
# 2         10  Australia        221               Almonds, with shell
# 3         10  Australia        711  Anise, badian, fennel, coriander
# 4         10  Australia        711  Anise, badian, fennel, coriander
#
#    Element Code         Element    Unit  Y1961 Y1961F  Y1962  ...     Y2015  \
# 0          5312  Area harvested      ha    NaN      M    NaN  ...   28190.0
# 1          5419           Yield   hg/ha    NaN    NaN    NaN  ...   45221.0
# 2          5510      Production  tonnes    NaN      M    NaN  ...  127479.0
# 3          5312  Area harvested      ha    NaN      M    NaN  ...     989.0
# 4          5419           Yield   hg/ha    NaN    NaN    NaN  ...   11608.0
#
#    Y2015F     Y2016  Y2016F     Y2017  Y2017F     Y2018  Y2018F     Y2019  \
# ...

# %%
data_analysis_dropna.head()
# Out:
#     Area Code       Area  Item Code       Item  Element Code Element   Unit  \
# 7          10  Australia        515     Apples          5419   Yield  hg/ha
# 10         10  Australia        526   Apricots          5419   Yield  hg/ha
# 13         10  Australia        367  Asparagus          5419   Yield  hg/ha
# 19         10  Australia        486    Bananas          5419   Yield  hg/ha
# 22         10  Australia         44     Barley          5419   Yield  hg/ha
#
#        Y1961 Y1961F     Y1962  ...     Y2015  Y2015F     Y2016  Y2016F  \
# 7   110682.0     Fc  122396.0  ...  159496.0      Fc  159467.0      Fc
# 10  107251.0     Fc  107251.0  ...   12438.0      Fc   18946.0      Fc
# 13   39833.0     Fc   39208.0  ...   51364.0      Fc   50799.0      Fc
# 19  119640.0     Fc  119640.0  ...  213797.0      Fc  213244.0      Fc
# 22    9759.0     Fc   10940.0  ...   21202.0      Fc   21892.0      Fc
#
#        Y2017  Y2017F     Y2018  Y2018F     Y2019  Y2019F
# ...

# %%
# sorting the data into specific columns
data_analysis_dropna[data_analysis_dropna['Area'] == 'Australia']
# Out:
#      Area Code       Area  Item Code                Item  Element Code  \
# 7           10  Australia        515              Apples          5419
# 10          10  Australia        526            Apricots          5419
# 13          10  Australia        367           Asparagus          5419
# 19          10  Australia        486             Bananas          5419
# 22          10  Australia         44              Barley          5419
# ..         ...        ...        ...                 ...           ...
# 288         10  Australia       1729     Treenuts, Total          5419
# 289         10  Australia       1729     Treenuts, Total          5510
# 290         10  Australia       1735  Vegetables Primary          5312
# 291         10  Australia       1735  Vegetables Primary          5419
# 292         10  Australia       1735  Vegetables Primary          5510
#
#             Element    Unit     Y1961 Y1961F     Y1962  ...      Y2015  \
# ...

# %%
# sorting the data according to Items
data_analysis_dropna[data_analysis_dropna['Item'] == 'Apples']
# Out:
#      Area Code         Area  Item Code    Item  Element Code Element   Unit  \
# 7           10    Australia        515  Apples          5419   Yield  hg/ha
# 880        156  New Zealand        515  Apples          5419   Yield  hg/ha
#
#         Y1961 Y1961F     Y1962  ...     Y2015  Y2015F     Y2016  Y2016F  \
# 7    110682.0     Fc  122396.0  ...  159496.0      Fc  159467.0      Fc
# 880  224096.0     Fc  271300.0  ...  540054.0      Fc  542995.0      Fc
#
#         Y2017  Y2017F     Y2018  Y2018F     Y2019  Y2019F
# 7    159513.0      Fc  159564.0      Fc  159614.0      Fc
# 880  545560.0      Fc  558529.0      Fc  567219.0      Fc
#
# [2 rows x 125 columns]

# %%
# Checking the group according to the Area and estimating its max
data_analysis_dropna.groupby('Area').max()
# Out:
#                   Area Code  Item Code                   Item  Element Code  \
# Area
# Australia                10       1841                  Wheat          5510
# Cook Islands             47       1841            Watermelons          5510
# Fiji                     66       1841                   Yams          5510
# French Polynesia         70       1841            Watermelons          5510
# Kiribati                 83       1841  Vegetables, fresh nes          5510
# Nauru                   148       1841  Vegetables, fresh nes          5510
# New Caledonia           153       1841                   Yams          5510
# New Zealand             156       1841                  Wheat          5510
# Niue                    160       1841                   Yams          5510
# Papua New Guinea        168       1841                   Yams          5510
# Samoa                   244       1841                   Yams          5510
# ...

# %%
# Checking the group according to the Area and estimating its counts
data_analysis_dropna.groupby('Area').count()
# Out:
#                   Area Code  Item Code  Item  Element Code  Element  Unit  \
# Area
# Australia               100        100   100           100      100   100
# Cook Islands             33         33    33            33       33    33
# Fiji                     60         60    60            60       60    60
# French Polynesia         63         63    63            63       63    63
# Kiribati                 32         32    32            32       32    32
# Nauru                    18         18    18            18       18    18
# New Caledonia            39         39    39            39       39    39
# New Zealand              76         76    76            76       76    76
# Niue                     29         29    29            29       29    29
# Papua New Guinea         87         87    87            87       87    87
# Samoa                    51         51    51            51       51    51
# Solomon Islands          63         63    63            63       63    63
# ...

# %%
data_analysis_dropna.stack([0])
# Out:
# 7     Area Code              10
#       Area            Australia
#       Item Code             515
#       Item               Apples
#       Element Code         5419
#                         ...
# 1653  Y2017F                  A
#       Y2018             13640.0
#       Y2018F                  A
#       Y2019             13804.0
#       Y2019F                  A
# Length: 97750, dtype: object

# %%
data_analysis_dropna.infer_objects()
# Out:
#       Area Code       Area  Item Code                     Item  Element Code  \
# 7            10  Australia        515                   Apples          5419
# 10           10  Australia        526                 Apricots          5419
# 13           10  Australia        367                Asparagus          5419
# 19           10  Australia        486                  Bananas          5419
# 22           10  Australia         44                   Barley          5419
# ...         ...        ...        ...                      ...           ...
# 1649        155    Vanuatu       1720  Roots and Tubers, Total          5419
# 1650        155    Vanuatu       1720  Roots and Tubers, Total          5510
# 1651        155    Vanuatu       1735       Vegetables Primary          5312
# 1652        155    Vanuatu       1735       Vegetables Primary          5419
# 1653        155    Vanuatu       1735       Vegetables Primary          5510
#
# ...

# %%
# Function to iterate over the rows of the dataframe rows and get the information
data_analysis_dropna_rows = data_analysis_dropna.iterrows()
for i in data_analysis_dropna_rows:
    print(i)
